# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("newstudent.csv")
df
# Out:
#     rollno name    course
# 0      101   jan  science
# 1      102   feb     math
# 2      103   mar       gk
# 3      104   apr  science
# 4      105   may     math
# 5      106   jun       gk
# 6      107   jul  science
# 7      108   aug     math
# 8      109   sep       gk
# 9      110   oct  science
# 10     111   nov     math
# 11     112   dec       gk
# 12     113   jan  science
# 13     114   feb     math

# %%
df.head()
# Out:
#    rollno name    course
# 0     101   jan  science
# 1     102   feb     math
# 2     103   mar       gk
# 3     104   apr  science
# 4     105   may     math

# %%
df.head(3)
# Out:
#    rollno name    course
# 0     101   jan  science
# 1     102   feb     math
# 2     103   mar       gk

# %%
df.tail(3)
# Out:
#     rollno name    course
# 11     112   dec       gk
# 12     113   jan  science
# 13     114   feb     math

# %%
df.shape[0]# row
# Out:
# 14

# %%
df.shape[1] #column
# Out:
# 3

# %%
df.columns
# Out:
# Index(['rollno', 'name ', 'course'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=14, step=1)

# %%
df["course"]
# Out:
# 0     science
# 1        math
# 2          gk
# 3     science
# 4        math
# 5          gk
# 6     science
# 7        math
# 8          gk
# 9     science
# 10       math
# 11         gk
# 12    science
# 13       math
# Name: course, dtype: object

# %%
df.describe()
# Out:
#          rollno
# count   14.0000
# mean   107.5000
# std      4.1833
# min    101.0000
# 25%    104.2500
# 50%    107.5000
# 75%    110.7500
# max    114.0000

# %%
df.describe(include="all")
# Out:
#           rollno name    course
# count    14.0000    14       14
# unique       NaN    12        3
# top          NaN   jan  science
# freq         NaN     2        5
# mean    107.5000   NaN      NaN
# std       4.1833   NaN      NaN
# min     101.0000   NaN      NaN
# 25%     104.2500   NaN      NaN
# 50%     107.5000   NaN      NaN
# 75%     110.7500   NaN      NaN
# max     114.0000   NaN      NaN

# %%
df.occupation.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15392\1530568230.py in ?()
# ----> 1 df.occupation.describe()
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'occupation'
