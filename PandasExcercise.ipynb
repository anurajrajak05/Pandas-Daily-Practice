# %% [markdown]
# -- Pandas:Excercise

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Q.1 Load .csv file

# %%
df = pd.read_csv("StudentPerformanceFactors.csv")
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                            No          7.0               79
# 1                            No          8.0               56
# 2                           Yes          7.0               91
# 3                           Yes          8.0               98
# 4                           Yes          6.0               65
# ...                         ...          ...              ...
# 6602                         No          7.0               76
# 6603                         No          NaN               81
# 6604                        Yes          6.0               65
# 6605                        Yes          6.0               91
# 6606                        Yes          9.0               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 0                 Low             Yes                0.0           Low
# 1                 Low             Yes                2.0        Medium
# 2              Medium             Yes                2.0        Medium
# 3              Medium             Yes                1.0        Medium
# 4              Medium             Yes                3.0        Medium
# ...               ...             ...                ...           ...
# 6602           Medium             Yes                1.0          High
# 6603           Medium             Yes                3.0           Low
# 6604              Low             Yes                3.0           Low
# 6605             High             Yes                2.0           Low
# 6606           Medium             Yes                0.0        Medium
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 0             Medium      Public       Positive                  3
# 1             Medium      Public       Negative                  4
# 2             Medium      Public        Neutral                  4
# 3             Medium      Public       Negative                  4
# 4               High      Public        Neutral                  4
# ...              ...         ...            ...                ...
# 6602          Medium      Public       Positive                  2
# 6603            High      Public       Positive                  2
# 6604          Medium      Public       Negative                  2
# 6605          Medium     Private       Positive                  3
# 6606          Medium      Public       Positive                  4
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  \
# 0                       No              High School               Near
# 1                       No                  College           Moderate
# 2                       No             Postgraduate               Near
# 3                       No              High School           Moderate
# 4                       No                  College               Near
# ...                    ...                      ...                ...
# 6602                    No              High School               Near
# 6603                    No              High School               Near
# 6604                    No             Postgraduate               Near
# 6605                    No              High School                Far
# 6606                    No             Postgraduate               Near
#
#       Gender  Exam_Score
# 0       Male          67
# 1     Female          61
# 2       Male          74
# 3       Male          71
# 4     Female          70
# ...      ...         ...
# 6602  Female          68
# 6603  Female          69
# 6604  Female          68
# 6605  Female          68
# 6606    Male          64
#
# [6607 rows x 20 columns]

# %% [markdown]
# Q.2 Display top 3 rows

# %%
df.head(3)
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No          7.0               79              Low
# 1                         No          8.0               56              Low
# 2                        Yes          7.0               91           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                0.0           Low          Medium
# 1             Yes                2.0        Medium          Medium
# 2             Yes                2.0        Medium          Medium
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# 0      Public       Positive                  3                    No
# 1      Public       Negative                  4                    No
# 2      Public        Neutral                  4                    No
#
#   Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# 0              High School               Near    Male          67
# 1                  College           Moderate  Female          61
# 2             Postgraduate               Near    Male          74

# %% [markdown]
# Q.3 Display last 3 rows

# %%
df.tail(3)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 6604                        Yes          6.0               65
# 6605                        Yes          6.0               91
# 6606                        Yes          9.0               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 6604              Low             Yes                3.0           Low
# 6605             High             Yes                2.0           Low
# 6606           Medium             Yes                0.0        Medium
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 6604          Medium      Public       Negative                  2
# 6605          Medium     Private       Positive                  3
# 6606          Medium      Public       Positive                  4
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  \
# 6604                    No             Postgraduate               Near
# 6605                    No              High School                Far
# 6606                    No             Postgraduate               Near
#
#       Gender  Exam_Score
# 6604  Female          68
# 6605  Female          68
# 6606    Male          64

# %% [markdown]
# Q.4 Find number of rows and number of columns

# %%
df.shape
# Out:
# (6607, 20)

# %% [markdown]
# Q.5 Get information like total number of rows,total number of columns,data types of each column and memory requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6594 non-null   float64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6604 non-null   float64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
#  13  Peer_Influence              6607 non-null   object
#  14  Physical_Activity           6607 non-null   int64
#  15  Learning_Disabilities       6607 non-null   object
#  16  Parental_Education_Level    6517 non-null   object
#  17  Distance_from_Home          6540 non-null   object
#  18  Gender                      6607 non-null   object
#  19  Exam_Score                  6607 non-null   int64
# dtypes: float64(2), int64(5), object(13)
# memory usage: 1.0+ MB

# %% [markdown]
# Q.6 Check null values in the dataset

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                   13
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              3
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %% [markdown]
# Q.7 Get overall statistics about the dataframe

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000  6594.000000      6607.000000
# mean       19.975329    79.977448     7.029421        75.070985
# std         5.990594    11.547475     1.468528        14.400397
# min         1.000000    60.000000     4.000000        50.000000
# 25%        16.000000    70.000000     6.000000        63.000000
# 50%        20.000000    80.000000     7.000000        75.000000
# 75%        24.000000    90.000000     8.000000        88.000000
# max        44.000000   100.000000    10.000000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count         6604.00000        6607.000000  6607.000000
# mean             1.49364           2.967610    67.235659
# std              1.23068           1.031231     3.890456
# min              0.00000           0.000000    55.000000
# 25%              1.00000           2.000000    65.000000
# 50%              1.00000           3.000000    67.000000
# 75%              2.00000           4.000000    69.000000
# max              8.00000           6.000000   101.000000

# %% [markdown]
# Q.8 Find unique values from the gender column

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# Q.9 Find the number of unique values from the gender column

# %%
df['Gender'].nunique()
# Out:
# 2

# %% [markdown]
# Q.10 Display count of unique values in gender column

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      3814
# Female    2793
# Name: count, dtype: int64

# %% [markdown]
# Q.11 Find the total number of students having marks between 70 to 90(inclusive) using between
# method.

# %%
df["Exam_Score"].between(70, 90).sum()
# Out:
# np.int64(1603)

# %% [markdown]
# Q.12 Find average marks.

# %%
df['Exam_Score'].mean()
# Out:
# np.float64(67.23565914938702)

# %% [markdown]
# Q.13 Using apply method get increment the marks of each student by 5

# %%
df["Exam_Score"] = df["Exam_Score"].apply(lambda x: x + 5)
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No          7.0               79              Low
# 1                         No          8.0               56              Low
# 2                        Yes          7.0               91           Medium
# 3                        Yes          8.0               98           Medium
# 4                        Yes          6.0               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                0.0           Low          Medium
# 1             Yes                2.0        Medium          Medium
# 2             Yes                2.0        Medium          Medium
# 3             Yes                1.0        Medium          Medium
# 4             Yes                3.0        Medium            High
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# 0      Public       Positive                  3                    No
# 1      Public       Negative                  4                    No
# 2      Public        Neutral                  4                    No
# 3      Public       Negative                  4                    No
# 4      Public        Neutral                  4                    No
#
#   Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# 0              High School               Near       1          92
# 1                  College           Moderate       0          86
# 2             Postgraduate               Near       1          99
# 3              High School           Moderate       1          96
# 4                  College               Near       0          95

# %% [markdown]
# Q.14 Count the length of student name.

# %% [markdown]
# Q.15 Replace the male by 1 and female by 0 in gender column

# %%
df["Gender"] = df["Gender"].replace({"Male":1,"Female":0})

df.head()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24672\2865535459.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Gender"] = df["Gender"].replace({"Male":1,"Female":0})
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No          7.0               79              Low
# 1                         No          8.0               56              Low
# 2                        Yes          7.0               91           Medium
# 3                        Yes          8.0               98           Medium
# 4                        Yes          6.0               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                0.0           Low          Medium
# 1             Yes                2.0        Medium          Medium
# 2             Yes                2.0        Medium          Medium
# 3             Yes                1.0        Medium          Medium
# 4             Yes                3.0        Medium            High
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# 0      Public       Positive                  3                    No
# 1      Public       Negative                  4                    No
# 2      Public        Neutral                  4                    No
# 3      Public       Negative                  4                    No
# 4      Public        Neutral                  4                    No
#
#   Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# 0              High School               Near       1          87
# 1                  College           Moderate       0          81
# 2             Postgraduate               Near       1          94
# 3              High School           Moderate       1          91
# 4                  College               Near       0          90

# %% [markdown]
# Q.16 Drop the column gender and marks in given dataset

# %%
df.drop(["Gender","Exam_Score"], axis=1)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                            No          7.0               79
# 1                            No          8.0               56
# 2                           Yes          7.0               91
# 3                           Yes          8.0               98
# 4                           Yes          6.0               65
# ...                         ...          ...              ...
# 6602                         No          7.0               76
# 6603                         No          NaN               81
# 6604                        Yes          6.0               65
# 6605                        Yes          6.0               91
# 6606                        Yes          9.0               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 0                 Low             Yes                0.0           Low
# 1                 Low             Yes                2.0        Medium
# 2              Medium             Yes                2.0        Medium
# 3              Medium             Yes                1.0        Medium
# 4              Medium             Yes                3.0        Medium
# ...               ...             ...                ...           ...
# 6602           Medium             Yes                1.0          High
# 6603           Medium             Yes                3.0           Low
# 6604              Low             Yes                3.0           Low
# 6605             High             Yes                2.0           Low
# 6606           Medium             Yes                0.0        Medium
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 0             Medium      Public       Positive                  3
# 1             Medium      Public       Negative                  4
# 2             Medium      Public        Neutral                  4
# 3             Medium      Public       Negative                  4
# 4               High      Public        Neutral                  4
# ...              ...         ...            ...                ...
# 6602          Medium      Public       Positive                  2
# 6603            High      Public       Positive                  2
# 6604          Medium      Public       Negative                  2
# 6605          Medium     Private       Positive                  3
# 6606          Medium      Public       Positive                  4
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home
# 0                       No              High School               Near
# 1                       No                  College           Moderate
# 2                       No             Postgraduate               Near
# 3                       No              High School           Moderate
# 4                       No                  College               Near
# ...                    ...                      ...                ...
# 6602                    No              High School               Near
# 6603                    No              High School               Near
# 6604                    No             Postgraduate               Near
# 6605                    No              High School                Far
# 6606                    No             Postgraduate               Near
#
# [6607 rows x 18 columns]

# %% [markdown]
# Q.17 Sort the data frame as per the marks column.

# %% [markdown]
# Q.18 Sort the data frame as per the marks column as well as gender column.

# %% [markdown]
# Q.19 Display the name of those students who scored 89,70,65,60 marks.

# %%
df[df["Exam_Score"].isin([89,70,65,60])]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 15               17          68               Medium              Medium
# 25               21          62                 High                 Low
# 29               18          66                 High                High
# 36               21          65               Medium                 Low
# 39               21          65                  Low              Medium
# ...             ...         ...                  ...                 ...
# 6577             14          73                 High              Medium
# 6578             22          76                  Low                High
# 6593             16          75                 High                 Low
# 6598              9          87                  Low              Medium
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 15                           No          8.0               70
# 25                          Yes          6.0               54
# 29                           No          4.0               51
# 36                          Yes          7.0               91
# 39                          Yes          6.0               98
# ...                         ...          ...              ...
# 6577                        Yes          6.0               57
# 6578                         No          5.0               65
# 6593                        Yes         10.0               53
# 6598                        Yes          6.0               64
# 6606                        Yes          9.0               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 15             Medium             Yes                2.0        Medium
# 25               High             Yes                0.0          High
# 29                Low             Yes                2.0           Low
# 36                Low             Yes                2.0        Medium
# 39                Low             Yes                1.0        Medium
# ...               ...             ...                ...           ...
# 6577             High             Yes                2.0        Medium
# 6578              Low             Yes                0.0        Medium
# 6593             High             Yes                0.0           Low
# 6598           Medium             Yes                1.0          High
# 6606           Medium             Yes                0.0        Medium
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 15            Medium     Private       Positive                  4
# 25              High      Public       Positive                  3
# 29            Medium     Private        Neutral                  2
# 36              High      Public       Positive                  3
# 39              High      Public       Negative                  4
# ...              ...         ...            ...                ...
# 6577          Medium      Public        Neutral                  4
# 6578            High      Public        Neutral                  3
# 6593             Low      Public       Positive                  4
# 6598          Medium      Public        Neutral                  2
# 6606          Medium      Public       Positive                  4
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  \
# 15                      No              High School               Near
# 25                      No             Postgraduate                Far
# 29                      No                  College               Near
# 36                      No              High School                Far
# 39                      No              High School               Near
# ...                    ...                      ...                ...
# 6577                    No              High School           Moderate
# 6578                    No              High School                Far
# 6593                    No                  College               Near
# 6598                    No              High School               Near
# 6606                    No             Postgraduate               Near
#
#       Gender  Exam_Score
# 15         0          89
# 25         1          89
# 29         1          89
# 36         0          89
# 39         1          89
# ...      ...         ...
# 6577       0          89
# 6578       0          89
# 6593       0          89
# 6598       0          89
# 6606       1          89
#
# [501 rows x 20 columns]

# %% [markdown]
# Q.20 Remove the duplicates Rows if found and store only last unique value.

# %%
df.drop_duplicates(keep="last", inplace=True)
