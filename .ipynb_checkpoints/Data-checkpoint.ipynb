# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("newstudent.csv")
df
# Out:
#     rollno name    course
# 0      101   jan  science
# 1      102   feb     math
# 2      103   mar       gk
# 3      104   apr  science
# 4      105   may     math
# 5      106   jun       gk
# 6      107   jul  science
# 7      108   aug     math
# 8      109   sep       gk
# 9      110   oct  science
# 10     111   nov     math
# 11     112   dec       gk
# 12     113   jan  science
# 13     114   feb     math

# %%
df.head()
# Out:
#    rollno name    course
# 0     101   jan  science
# 1     102   feb     math
# 2     103   mar       gk
# 3     104   apr  science
# 4     105   may     math

# %%
df.head(3)
# Out:
#    rollno name    course
# 0     101   jan  science
# 1     102   feb     math
# 2     103   mar       gk

# %%
df.tail(3)
# Out:
#     rollno name    course
# 11     112   dec       gk
# 12     113   jan  science
# 13     114   feb     math

# %%
df.shape[0]# row
# Out:
# 14

# %%
df.shape[1] #column
# Out:
# 3

# %%
df.columns
# Out:
# Index(['rollno', 'name ', 'course'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=14, step=1)

# %%
df["course"]
# Out:
# 0     science
# 1        math
# 2          gk
# 3     science
# 4        math
# 5          gk
# 6     science
# 7        math
# 8          gk
# 9     science
# 10       math
# 11         gk
# 12    science
# 13       math
# Name: course, dtype: object

# %%
df.describe()
# Out:
#          rollno
# count   14.0000
# mean   107.5000
# std      4.1833
# min    101.0000
# 25%    104.2500
# 50%    107.5000
# 75%    110.7500
# max    114.0000

# %%
df.describe(include="all")
# Out:
#           rollno name    course
# count    14.0000    14       14
# unique       NaN    12        3
# top          NaN   jan  science
# freq         NaN     2        5
# mean    107.5000   NaN      NaN
# std       4.1833   NaN      NaN
# min     101.0000   NaN      NaN
# 25%     104.2500   NaN      NaN
# 50%     107.5000   NaN      NaN
# 75%     110.7500   NaN      NaN
# max     114.0000   NaN      NaN

# %%
List=[["Sun","Mon","Tue","Wed"],["Jan","Feb","Mar","Apr"]]
data=pd.DataFrame(List)
data
# Out:
#      0    1    2    3
# 0  Sun  Mon  Tue  Wed
# 1  Jan  Feb  Mar  Apr

# %%
List=[["Sun","Mon","Tue","Wed"],["Jan","Feb","Mar","Apr"]]
data=pd.DataFrame(List)
data
# Out:
#      0    1    2    3
# 0  Sun  Mon  Tue  Wed
# 1  Jan  Feb  Mar  Apr

# %%
A=[["Sun","Mon","Tue","Wed"],["Jan","Feb","Mar","Apr"]]
dt=pd.DataFrame(A)
print(dt.T)
# Out:
#      0    1
# 0  Sun  Jan
# 1  Mon  Feb
# 2  Tue  Mar
# 3  Wed  Apr

# %%
A=np.array([["Sun","Mon","Tue","Wed"],["Jan","Feb","Mar","Apr"]]).reshape(4,2)
dt=pd.DataFrame(A)
print(dt)
# Out:
#      0    1
# 0  Sun  Mon
# 1  Tue  Wed
# 2  Jan  Feb
# 3  Mar  Apr

# %%
A={"weekdays":["Sun","Mon","Tue","Wed"],"monthname":["Jan","Feb","Mar","Apr"]}
dt=pd.DataFrame(A)
print(dt)
# Out:
#   weekdays monthname
# 0      Sun       Jan
# 1      Mon       Feb
# 2      Tue       Mar
# 3      Wed       Apr

# %%
A={"weekdays":["Sun","Mon","Tue","Wed"],"monthname":["Jan","Feb","Mar","Apr"]}
dt=pd.DataFrame(A,columns=['weekdays','monthname'])
print(dt)
# Out:
#   weekdays monthname
# 0      Sun       Jan
# 1      Mon       Feb
# 2      Tue       Mar
# 3      Wed       Apr

# %%
A={"weekdays":["Sun","Mon","Tue","Wed"],"monthname":["Jan","Feb","Mar","Apr"]}
dt=pd.DataFrame(A,columns=["s1","s2","s3","s4"])
print(dt)
# Out:
# Empty DataFrame
# Columns: [s1, s2, s3, s4]
# Index: []

# %%
# ager string huaa to => count,unique,top,freq

# %%
# A=np.array([["Sun","Mon","Tue","Wed"],["Jan","Feb","Mar","Apr"]]).reshape(4,2)
# dt=pd.DataFrame(A)
# print(dt.columns())

# %%
A=np.array([["Sun","Mon","Tue","Wed"],["Jan","Feb","Mar","Apr"]]).reshape(4,2)
dt=pd.DataFrame(A)
print(dt.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4 non-null      object
#  1   1       4 non-null      object
# dtypes: object(2)
# memory usage: 196.0+ bytes
# None

# %%
A=np.array([["Sun","Mon","Tue","Wed"],["Jan","Feb","Mar","Apr"]]).reshape(4,2)
dt=pd.DataFrame(A)
print(dt.describe())
# Out:
#           0    1
# count     4    4
# unique    4    4
# top     Sun  Mon
# freq      1    1

# %%
A=np.array([["Sun","Mon","Tue","Wed"],["Jan","Feb","Mar","Apr"]]).reshape(4,2)
dt=pd.DataFrame(A)
print(dt.max())
# Out:
# 0    Tue
# 1    Wed
# dtype: object

# %%
A=np.array([["Sun","Mon","Tue","Wed"],["Jan","Feb","Mar","Apr"]]).reshape(4,2)
dt=pd.DataFrame(A)
print(dt.min())
# Out:
# 0    Jan
# 1    Apr
# dtype: object

# %%
A=np.array([["Sun","Mon","Tue","Wed"],["Jan","Feb","Mar","Apr"]]).reshape(4,2)
dt=pd.DataFrame(A)
print(dt.isnull())
# Out:
#        0      1
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False

# %%
j={"Rno":[101,1002,103,104,105],"marks":[89,None,96,None,67]}
df=pd.DataFrame(j)
print(df)
# Out:
#     Rno  marks
# 0   101   89.0
# 1  1002    NaN
# 2   103   96.0
# 3   104    NaN
# 4   105   67.0

# %%
j={"Rno":[101,1002,103,104,105],"marks":[89,55,96,88,67]}
df=pd.DataFrame(j)
print(df)
# Out:
#     Rno  marks
# 0   101     89
# 1  1002     55
# 2   103     96
# 3   104     88
# 4   105     67

# %%
j={"Rno":[101,1002,103,104,105],"marks":[89,None,96,None,67]}
df=pd.DataFrame(j)
print(df)
# Out:
#     Rno  marks
# 0   101   89.0
# 1  1002    NaN
# 2   103   96.0
# 3   104    NaN
# 4   105   67.0

# %%
j={"Rno":[101,1002,103,104,105],"marks":[89,None,96,None,67]}
df=pd.DataFrame(j)
print(df.isnull())
# Out:
#      Rno  marks
# 0  False  False
# 1  False   True
# 2  False  False
# 3  False   True
# 4  False  False

# %%
j={"Rno":[101,1002,103,104,105],"marks":[89,None,96,None,67]}
df=pd.DataFrame(j)
print(df.isnull().count())
# Out:
# Rno      5
# marks    5
# dtype: int64

# %%
df={"Name":["anup","ravi","sohan","punit","deepak"],"salary":[20000,35000,25000,20000,40000]}
df=pd.DataFrame(df)
print(df)
print(df.isnull())
# Out:
#      Name  salary
# 0    anup   20000
# 1    ravi   35000
# 2   sohan   25000
# 3   punit   20000
# 4  deepak   40000
#     Name  salary
# 0  False   False
# 1  False   False
# 2  False   False
# 3  False   False
# 4  False   False

# %%
df={"Name":["anup","ravi","sohan","punit","deepak"],"salary":[20000,35000,None,20000,None]}
df=pd.DataFrame(df)
print(df)
print(df.isnull().sum())
print(df.duplicated())
# Out:
#      Name   salary
# 0    anup  20000.0
# 1    ravi  35000.0
# 2   sohan      NaN
# 3   punit  20000.0
# 4  deepak      NaN
# Name      0
# salary    2
# dtype: int64
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df={"Name":["anup","ravi","sohan","punit","deepak"],"salary":[20000,35000,None,20000,None]}
df=pd.DataFrame(df)
print(df)
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
#      Name   salary
# 0    anup  20000.0
# 1    ravi  35000.0
# 2   sohan      NaN
# 3   punit  20000.0
# 4  deepak      NaN
# Name      0
# salary    2
# dtype: int64
# 0

# %%
df={"Name":["anup","punit","sohan","punit","deepak"],"salary":[20000,20000,None,20000,None]}
df=pd.DataFrame(df)
print(df)
print(df.isnull().sum())
print(df.duplicated())
# Out:
#      Name   salary
# 0    anup  20000.0
# 1   punit  20000.0
# 2   sohan      NaN
# 3   punit  20000.0
# 4  deepak      NaN
# Name      0
# salary    2
# dtype: int64
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool

# %%
df={"Name":["anup","punit","sohan","punit","deepak"],"salary":[20000,20000,None,20000,None]}
df=pd.DataFrame(df)
print(df)
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
#      Name   salary
# 0    anup  20000.0
# 1   punit  20000.0
# 2   sohan      NaN
# 3   punit  20000.0
# 4  deepak      NaN
# Name      0
# salary    2
# dtype: int64
# 1

# %%
df={"Name":["anup","punit","sohan","punit","deepak"],"salary":[20000,20000,None,20000,None]}
df=pd.DataFrame(df)
print(df)
df['Name']
df['salary']

df.rename(columns={"salary": "package"})
# Out:
#      Name   salary
# 0    anup  20000.0
# 1   punit  20000.0
# 2   sohan      NaN
# 3   punit  20000.0
# 4  deepak      NaN
#      Name  package
# 0    anup  20000.0
# 1   punit  20000.0
# 2   sohan      NaN
# 3   punit  20000.0
# 4  deepak      NaN

# %%
df={"Name":["anup","punit","sohan","punit","deepak"],"salary":[20000,20000,None,20000,None]}
df=pd.DataFrame(df)
print(df)
df['Name']
df['salary']

df.rename(columns={"salary": "package"}, inplace=True)
# Out:
#      Name   salary
# 0    anup  20000.0
# 1   punit  20000.0
# 2   sohan      NaN
# 3   punit  20000.0
# 4  deepak      NaN

# %%
df={"Name":["anup","punit","sohan","punit","deepak"],"salary":[20000,20000,None,20000,None]}
df=pd.DataFrame(df)
print(df)
df['Name']
df['salary']

df.rename(columns={"salary": "package"}, inplace=True)
df["package"].var()
# Out:
#      Name   salary
# 0    anup  20000.0
# 1   punit  20000.0
# 2   sohan      NaN
# 3   punit  20000.0
# 4  deepak      NaN
# 0.0

# %%
df={"Name":["anup","punit","sohan","punit","deepak"],"salary":[20000,20000,None,20000,None]}
df=pd.DataFrame(df)
print(df)
# df['Name']
# df['salary']


# df.rename(columns={"salary": "package"}, inplace=True)
# df["package"].var()
df["city"]=["Bhopal","indore","Bhopal","ujjain","nagpur"]
df
# Out:
#      Name   salary
# 0    anup  20000.0
# 1   punit  20000.0
# 2   sohan      NaN
# 3   punit  20000.0
# 4  deepak      NaN
#      Name   salary    city
# 0    anup  20000.0  Bhopal
# 1   punit  20000.0  indore
# 2   sohan      NaN  Bhopal
# 3   punit  20000.0  ujjain
# 4  deepak      NaN  nagpur

# %%
tp={"Name":"Amit","marks":87}
tp
# Out:
# {'Name': 'Amit', 'marks': 87}

# %%
tp={"Name":"Amit","marks":87}
tp["name"]=20
tp
# Out:
# {'Name': 'Amit', 'marks': 87, 'name': 20}

# %%
df={"Name":["anup","punit","sohan","punit","deepak"],"salary":[20000,20000,None,20000,None]}
df=pd.DataFrame(df)
print(df)

df["city"]=["Bhopal","indore","Bhopal","ujjain","nagpur"]
# df.head(2)
df[0:2]
df.set_index('Name')
# Out:
#      Name   salary
# 0    anup  20000.0
# 1   punit  20000.0
# 2   sohan      NaN
# 3   punit  20000.0
# 4  deepak      NaN
#          salary    city
# Name
# anup    20000.0  Bhopal
# punit   20000.0  indore
# sohan       NaN  Bhopal
# punit   20000.0  ujjain
# deepak      NaN  nagpur

# %%
df={"Name":["anup","punit","sohan","punit","deepak"],"salary":[20000,20000,None,20000,None]}
df=pd.DataFrame(df)
print(df)

df["city"]=["Bhopal","indore","Bhopal","ujjain","nagpur"]

df = df.set_index('Name')
df[0:3]
# Out:
#      Name   salary
# 0    anup  20000.0
# 1   punit  20000.0
# 2   sohan      NaN
# 3   punit  20000.0
# 4  deepak      NaN
#         salary    city
# Name
# anup   20000.0  Bhopal
# punit  20000.0  indore
# sohan      NaN  Bhopal

# %%
df={"Name":["anup","punit","sohan","punit","deepak"],"salary":[20000,20000,None,20000,None]}
df=pd.DataFrame(df)
print(df)

df["city"]=["Bhopal","indore","Bhopal","ujjain","nagpur"]

df = df.set_index('Name')
df["anup":"sohan"]
# Out:
#      Name   salary
# 0    anup  20000.0
# 1   punit  20000.0
# 2   sohan      NaN
# 3   punit  20000.0
# 4  deepak      NaN
#         salary    city
# Name
# anup   20000.0  Bhopal
# punit  20000.0  indore
# sohan      NaN  Bhopal

# %%
df.loc["anup":"sohan"] # label Based searching # non interger
# Out:
#         salary    city
# Name
# anup   20000.0  Bhopal
# punit  20000.0  indore
# sohan      NaN  Bhopal

# %%
df.iloc[0:2] # index(integer) based searching
# Out:
#         salary    city
# Name
# anup   20000.0  Bhopal
# punit  20000.0  indore

# %%
A = {"Name":["Govind","Rihaan","Himesh","Tanishq"],"salary":[45000,30000,20000,25000], "Age":[20,26,23,90]}
df=pd.DataFrame(A)
print(df)
df
df.loc[[0,1],["salary","Age"]]
B = df.iloc[0:2,1:3]
B
# Out:
#       Name  salary  Age
# 0   Govind   45000   20
# 1   Rihaan   30000   26
# 2   Himesh   20000   23
# 3  Tanishq   25000   90
#    salary  Age
# 0   45000   20
# 1   30000   26

# %%
df.columns
# Out:
# Index(['Name', 'salary', 'Age'], dtype='object')

# %%
df["salary"]
# Out:
# 0    45000
# 1    30000
# 2    20000
# 3    25000
# Name: salary, dtype: int64

# %%
df["salary"].astype(float)
# Out:
# 0    45000.0
# 1    30000.0
# 2    20000.0
# 3    25000.0
# Name: salary, dtype: float64

# %%
df["salary"]=df["salary"].astype(float)
df
# Out:
#       Name   salary  Age
# 0   Govind  45000.0   20
# 1   Rihaan  30000.0   26
# 2   Himesh  20000.0   23
# 3  Tanishq  25000.0   90

# %%
df["salary"].astype(int)
# Out:
# 0    45000
# 1    30000
# 2    20000
# 3    25000
# Name: salary, dtype: int64

# %% [markdown]
# # Between Function

# %%
df["salary"]=df["salary"].astype(float)
df[df["salary"].between(10000,30000)]
# Out:
#       Name   salary  Age
# 1   Rihaan  30000.0   26
# 2   Himesh  20000.0   23
# 3  Tanishq  25000.0   90

# %%
df["salary"]=df["salary"].astype(float)
df[df["Name"].between("Rihaan","Tanishq")]
# Out:
#       Name   salary  Age
# 1   Rihaan  30000.0   26
# 3  Tanishq  25000.0   90

# %%
df["Name"] = df["Name"].replace("Himesh","Somesh")
df
# Out:
#       Name   salary  Age
# 0   Govind  45000.0   20
# 1   Rihaan  30000.0   26
# 2   Somesh  20000.0   23
# 3  Tanishq  25000.0   90

# %%
df[df["Name"].between("Rihaan","Tanishq")]
# Out:
#       Name   salary  Age
# 1   Rihaan  30000.0   26
# 2   Somesh  20000.0   23
# 3  Tanishq  25000.0   90

# %% [markdown]
# ### Drop function in duplicate

# %%
B = {"Name":[None,"Rihaan","Himesh","Tanishq"],"salary":[None,30000,20000,None], "Age":[None,26,23,90]}
df=pd.DataFrame(B)
df
df.dropna() # Drop entire row where it found null value 
df
df.dropna(how="all")
# Out:
#       Name   salary   Age
# 1   Rihaan  30000.0  26.0
# 2   Himesh  20000.0  23.0
# 3  Tanishq      NaN  90.0
