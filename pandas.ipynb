# %%
import pandas as pd

import numpy as np

# %%
# series & Dataframe 
# series is called 1D  array 
# series will be created by Numpy array , list Tuple Dictionary as well as. csv, . sql etc

# %%
A=[10,2,45,6,7]
s=pd.Series(A)
print(s)
# Out:
# 0    10
# 1     2
# 2    45
# 3     6
# 4     7
# dtype: int64

# %%
A=(10,2,45,6,7)                     # list aar tuple me indexing 
s=pd.Series(A)
print(s)
# Out:
# 0    10
# 1     2
# 2    45
# 3     6
# 4     7
# dtype: int64

# %%
D={"sun":101,"mon":102,"tue":103}
s=pd.Series(D)
print(s)
# Out:
# sun    101
# mon    102
# tue    103
# dtype: int64

# %%
# by  default value tuple hoti  hai ex 1,2,3,4,5

# %%
R = 1,2,3,4,5
s=pd.Series(R)
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
R = 32,34,45,21,2
s=pd.Series(R)
print(s)
# Out:
# 0    32
# 1    34
# 2    45
# 3    21
# 4     2
# dtype: int64

# %%
x,y=12,20  # unpacking 
print(x)
print(y)
# Out:
# 12
# 20

# %%
n=np.array(range(5))
print(n)
Ns=pd.Series(n)
print(Ns)
# Out:
# [0 1 2 3 4]
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
A= [[1,2,3],[4,5,6],[7,8,9]]
print(A)
ws=pd.Series(A)
print(ws)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# 0    [1, 2, 3]
# 1    [4, 5, 6]
# 2    [7, 8, 9]
# dtype: object

# %%
A= [[1,3,3],[1,3,3],[1,3,3]]
print(A)
ws=pd.Series(A)
print(ws)
# Out:
# [[1, 3, 3], [1, 3, 3], [1, 3, 3]]
# 0    [1, 3, 3]
# 1    [1, 3, 3]
# 2    [1, 3, 3]
# dtype: object

# %%
A= [[1,2,3],[4,5,6],[7,8,9]]
print(A)
ws=pd.Series(A)
print(ws[1][1])
print(ws)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# 5
# 0    [1, 2, 3]
# 1    [4, 5, 6]
# 2    [7, 8, 9]
# dtype: object

# %%
A= [[1,2,3],[4,5,6],[7,8,9]]
print(A)
ws=pd.Series(A)
print(ws)
print(ws[1][1])
print(ws[0][1])
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# 0    [1, 2, 3]
# 1    [4, 5, 6]
# 2    [7, 8, 9]
# dtype: object
# 5
# 2

# %%
A= [[1,2,3],[4,5,6],[7,8,9]]
print(A)
ws=pd.Series(A)
print(ws)
print(ws[1:3][0:3])
print(ws[0][1])
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# 0    [1, 2, 3]
# 1    [4, 5, 6]
# 2    [7, 8, 9]
# dtype: object
# 1    [4, 5, 6]
# 2    [7, 8, 9]
# dtype: object
# 2

# %%
Name = ["Amit","Rohan","Govind","Honey"]
print(Name)
score = [89,56,78,65]
print(score)
ds=pd.Series(score,index=Name)
print(ds)
# Out:
# ['Amit', 'Rohan', 'Govind', 'Honey']
# [89, 56, 78, 65]
# Amit      89
# Rohan     56
# Govind    78
# Honey     65
# dtype: int64

# %%
Name = ["Amit","Rohan","Govind","Honey"]
print(Name)
score = [89,56,78,65]
print(score)
ds=pd.Series(Name,index=score)
print(ds)
# Out:
# ['Amit', 'Rohan', 'Govind', 'Honey']
# [89, 56, 78, 65]
# 89      Amit
# 56     Rohan
# 78    Govind
# 65     Honey
# dtype: object

# %%
Name = ["Amit","Rohan","Govind","Honey","ram"]
print(Name)
score = [89,56,78,65,33]
print(score)
ds=pd.Series(score,index=Name)
print(ds)
# Out:
# ['Amit', 'Rohan', 'Govind', 'Honey', 'ram']
# [89, 56, 78, 65, 33]
# Amit      89
# Rohan     56
# Govind    78
# Honey     65
# ram       33
# dtype: int64

# %%
Y = {"Name":[["A","B","C"],["X","Y","Z"]], "Age":[[19,20,21],[22,23,24]]}
print(Y)
# Out:
# {'Name': [['A', 'B', 'C'], ['X', 'Y', 'Z']], 'Age': [[19, 20, 21], [22, 23, 24]]}

# %%
Y = {"Name":[["A","B","C"],["X","Y","Z"]], "Age":[[19,20,21],[22,23,24]]}
print(Y)
# Out:
# {'Name': [['A', 'B', 'C'], ['X', 'Y', 'Z']], 'Age': [[19, 20, 21], [22, 23, 24]]}

# %%
Result = ["pass","pass","fail","pass","pass","fail"]
Rs=pd.Series(Result)
print(Rs)
# Out:
# 0    pass
# 1    pass
# 2    fail
# 3    pass
# 4    pass
# 5    fail
# dtype: object

# %%
Student=["Sumit","Rav","Tapen","Romi","Pinaki","Rohan"]
Ss=pd.Series(Student)
print(Ss)
# Out:
# 0     Sumit
# 1       Rav
# 2     Tapen
# 3      Romi
# 4    Pinaki
# 5     Rohan
# dtype: object

# %%
Result = ["pass","pass","fail","pass","pass","fail"]
Rs=pd.Series(Result)
print(Rs)

Student=["Sumit","Rav","Tapen","Romi","Pinaki","Rohan"]
Ss=pd.Series(Student)
print(Ss)

Ss.size
Ss.dtype
# Out:
# 0    pass
# 1    pass
# 2    fail
# 3    pass
# 4    pass
# 5    fail
# dtype: object
# 0     Sumit
# 1       Rav
# 2     Tapen
# 3      Romi
# 4    Pinaki
# 5     Rohan
# dtype: object
# dtype('O')

# %%
Student=["Sumit","Rav","Tapen","Romi","Pinaki","Rohan"]
Ss=pd.Series(Student)
print(Ss)

Ss.size
# Ss.dtype
# Out:
# 0     Sumit
# 1       Rav
# 2     Tapen
# 3      Romi
# 4    Pinaki
# 5     Rohan
# dtype: object
# 6

# %% [markdown]
# ### TRUE condition in unique

# %%
Result = ["pass","pass","fail","pass","pass","fail"]
Rs=pd.Series(Result)
# print(Rs)

Student=["Sumit","Ravi","Tapen","Romi","Pinaki","Rohan"]
Ss=pd.Series(Student,name="cybrom")
print(Ss.is_unique)
# Out:
# True

# %% [markdown]
# ### false condition in unique

# %%
Result = ["pass","pass","fail","pass","pass","fail"]
Rs=pd.Series(Result)
print(Rs.is_unique)
# Out:
# False

# %%
Result = ["pass","pass","fail","pass","pass","fail"]
Rs=pd.Series(Result)
print(Rs)
print(Rs.values)
# Out:
# 0    pass
# 1    pass
# 2    fail
# 3    pass
# 4    pass
# 5    fail
# dtype: object
# ['pass' 'pass' 'fail' 'pass' 'pass' 'fail']

# %% [markdown]
# ### index

# %%
Result = ["pass","pass","fail","pass","pass","fail"]
Rs=pd.Series(Result)
print(Rs)
print(Rs.index)
# Out:
# 0    pass
# 1    pass
# 2    fail
# 3    pass
# 4    pass
# 5    fail
# dtype: object
# RangeIndex(start=0, stop=6, step=1)

# %%
T=pd.Series(Result,index=Student)
print(T)
# Out:
# Sumit     pass
# Ravi      pass
# Tapen     fail
# Romi      pass
# Pinaki    pass
# Rohan     fail
# dtype: object

# %%
print(T.index)
# Out:
# Index(['Sumit', 'Ravi', 'Tapen', 'Romi', 'Pinaki', 'Rohan'], dtype='object')

# %% [markdown]
# ### Methods:(head(),tail(),sample(),value_counts(),sort_values(),sort_index(),Concept of method chaining.

# %% [markdown]
# ### head function

# %%
student=["Sumit", "Ravi", "Tapen", "Romi", "Pinaki", "Rohan","Ramu", "Raju" ,"Karan","Priya"]
W=pd.Series(student)
print(W.head())
# Out:
# 0     Sumit
# 1      Ravi
# 2     Tapen
# 3      Romi
# 4    Pinaki
# dtype: object

# %%
student=["Sumit", "Ravi", "Tapen", "Romi", "Pinaki", "Rohan","Ramu", "Raju" ,"Karan","Priya"]
df=pd.Series(student)
df.head()
# Out:
# 0     Sumit
# 1      Ravi
# 2     Tapen
# 3      Romi
# 4    Pinaki
# dtype: object

# %% [markdown]
# ### Tail funtion

# %%
student=["Sumit", "Ravi", "Tapen", "Romi", "Pinaki", "Rohan","Ramu", "Raju" ,"Karan","Priya"]
W=pd.Series(student)
print(W.tail())
# Out:
# 5    Rohan
# 6     Ramu
# 7     Raju
# 8    Karan
# 9    Priya
# dtype: object

# %%
student=["Sumit", "Ravi", "Tapen", "Romi", "Pinaki", "Rohan","Ramu", "Raju" ,"Karan","Priya"]
df=pd.Series(student)
df.tail()
# Out:
# 5    Rohan
# 6     Ramu
# 7     Raju
# 8    Karan
# 9    Priya
# dtype: object

# %%
student=["Sumit", "Ravi", "Tapen", "Romi", "Pinaki", "Rohan","Ramu", "Raju" ,"Karan","Priya"]
df=pd.Series(student)
df.tail(3)
# Out:
# 7     Raju
# 8    Karan
# 9    Priya
# dtype: object

# %% [markdown]
# ### Sample

# %%
student=["Sumit", "Ravi", "Tapen", "Romi", "Pinaki", "Rohan","Ramu", "Raju" ,"Karan","Priya"]
df=pd.Series(student)
df.sample()
# Out:
# 3    Romi
# dtype: object

# %%
student=["Sumit", "Ravi", "Tapen", "Romi", "Pinaki", "Rohan","Ramu", "Raju" ,"Karan","Priya"]
df=pd.Series(student)
df.sample(3)
# Out:
# 8    Karan
# 5    Rohan
# 2    Tapen
# dtype: object

# %% [markdown]
# ### Value Counts

# %%
student=["Sumit", "Ravi", "Tapen", "Ramu", "Pinaki", "Rohan","Ramu", "Ravi" ,"Karan","Ramu"]
df=pd.Series(student)
df.value_counts()
# Out:
# Ramu      3
# Ravi      2
# Sumit     1
# Tapen     1
# Pinaki    1
# Rohan     1
# Karan     1
# Name: count, dtype: int64

# %% [markdown]
# ### SORT VALUES in ASC ORDER

# %%
student=["Sumit", "Ravi", "Tapen", "Ramu", "Pinaki", "Rohan","Ramu", "Ravi" ,"Karan","Ramu"]
df=pd.Series(student)
df.sort_values()
# Out:
# 8     Karan
# 4    Pinaki
# 3      Ramu
# 6      Ramu
# 9      Ramu
# 1      Ravi
# 7      Ravi
# 5     Rohan
# 0     Sumit
# 2     Tapen
# dtype: object

# %% [markdown]
# ### SORT VALUES in DESC ORDER

# %%
student=["Sumit", "Ravi", "Tapen", "Ramu", "Pinaki", "Rohan","Ramu", "Ravi" ,"Karan","Ramu"]
df=pd.Series(student)
df.sort_values(ascending=False)
# Out:
# 2     Tapen
# 0     Sumit
# 5     Rohan
# 1      Ravi
# 7      Ravi
# 3      Ramu
# 6      Ramu
# 9      Ramu
# 4    Pinaki
# 8     Karan
# dtype: object

# %% [markdown]
# ### SORT INDEX USING IN ASC ORDER

# %%
student=["Sumit", "Ravi", "Tapen", "Ramu", "Pinaki", "Rohan","Ramu", "Ravi" ,"Karan","Ramu"]
df=pd.Series(student)
df.sort_index()
# Out:
# 0     Sumit
# 1      Ravi
# 2     Tapen
# 3      Ramu
# 4    Pinaki
# 5     Rohan
# 6      Ramu
# 7      Ravi
# 8     Karan
# 9      Ramu
# dtype: object

# %% [markdown]
# ### SORT INDEX USING IN DESC ORDER

# %%
student=["Sumit", "Ravi", "Tapen", "Ramu", "Pinaki", "Rohan","Ramu", "Ravi" ,"Karan","Ramu"]
df=pd.Series(student)
df.sort_index(ascending=False)
# Out:
# 9      Ramu
# 8     Karan
# 7      Ravi
# 6      Ramu
# 5     Rohan
# 4    Pinaki
# 3      Ramu
# 2     Tapen
# 1      Ravi
# 0     Sumit
# dtype: object

# %% [markdown]
# #### method of chaining.

# %%
student=["Sumit", "Ravi", "Tapen", "Ramu", "Pinaki", "Rohan","Ramu", "Ravi" ,"Karan","Ramu"]
df=pd.Series(student)
df.sort_index(ascending=False).head().values
# Out:
# array(['Ramu', 'Karan', 'Ravi', 'Ramu', 'Rohan'], dtype=object)

# %%
import pandas as pd

# %%
student=["Sumit", "Ravi", "Tapen", "Ramu", "Pinaki", "Rohan","Ramu", "Ravi" ,"Karan","Ramu"]
df=pd.Series(student)
df.sort_index(ascending=False).head(2).values
# Out:
# array(['Ramu', 'Karan'], dtype=object)

# %% [markdown]
# ### count function

# %%
A=[10,3,5,4,6,70,12,45]
df = pd.Series(A)
print(df)
print("counting=",df.count())
# Out:
# 0    10
# 1     3
# 2     5
# 3     4
# 4     6
# 5    70
# 6    12
# 7    45
# dtype: int64
# counting= 8

# %% [markdown]
# ### Product Function

# %%
A=[10,3,5,4,6,70,12,45]
df = pd.Series(A)
print(df)
print("Product=",df.product())
# Out:
# 0    10
# 1     3
# 2     5
# 3     4
# 4     6
# 5    70
# 6    12
# 7    45
# dtype: int64
# Product= 136080000

# %% [markdown]
# # SUM FUNCTION

# %%
A=[10,3,5,4,6,70,12,45]
df = pd.Series(A)
print(df)
print("sum=",df.sum())
# Out:
# 0    10
# 1     3
# 2     5
# 3     4
# 4     6
# 5    70
# 6    12
# 7    45
# dtype: int64
# sum= 155

# %% [markdown]
# ### MEAN FUNCTION

# %%
A=[10,3,5,4,6,70,12,45]
df = pd.Series(A)
print(df)
print("mean=",df.mean())
# Out:
# 0    10
# 1     3
# 2     5
# 3     4
# 4     6
# 5    70
# 6    12
# 7    45
# dtype: int64
# mean= 19.375

# %% [markdown]
# ### MODE FUNCTION
# ALP data hamesa mode se nikalte hai

# %%
A=[10,3,5,4,6,70,12,45]
df = pd.Series(A)
# print(df)
print("mode=",df.mode())
# Out:
# mode= 0     3
# 1     4
# 2     5
# 3     6
# 4    10
# 5    12
# 6    45
# 7    70
# dtype: int64

# %% [markdown]
# #### Standard deviation

# %%
A=[10,3,5,4,6,70,12,45]
df = pd.Series(A)
print(df)
print("Standard deviation=",df.std())
# Out:
# 0    10
# 1     3
# 2     5
# 3     4
# 4     6
# 5    70
# 6    12
# 7    45
# dtype: int64
# Standard deviation= 24.64570376933299

# %% [markdown]
# ### VARIANCE Function

# %%
A=[10,3,5,4,6,70,12,45]
df = pd.Series(A)
print(df)
print("variance=",df.var())
# Out:
# 0    10
# 1     3
# 2     5
# 3     4
# 4     6
# 5    70
# 6    12
# 7    45
# dtype: int64
# variance= 607.4107142857143

# %% [markdown]
# ### MIN Functiom

# %%
A=[10,3,5,4,6,70,12,45]
df = pd.Series(A)
print(df)
print("min=",df.min())
# Out:
# 0    10
# 1     3
# 2     5
# 3     4
# 4     6
# 5    70
# 6    12
# 7    45
# dtype: int64
# min= 3

# %% [markdown]
# ### MAX Function

# %%
A=[10,3,5,4,6,70,12,45]
df = pd.Series(A)
print(df)
print("max=",df.max())
# Out:
# 0    10
# 1     3
# 2     5
# 3     4
# 4     6
# 5    70
# 6    12
# 7    45
# dtype: int64
# max= 70

# %%
A=[10,32,3,2,42,34,4,3,2,1,1,22,35]
df = pd.Series(A)
print(df)
print("max=",df.max())
# Out:
# 0     10
# 1     32
# 2      3
# 3      2
# 4     42
# 5     34
# 6      4
# 7      3
# 8      2
# 9      1
# 10     1
# 11    22
# 12    35
# dtype: int64
# max= 42

# %% [markdown]
# ### Describe function
# Describe function only interger me work karta hai and describe function ko 5 funtion bhi bolte hai

# %%
A=[10,3,5,4,6,70,12,45]
df = pd.Series(A)
print(df)
print("describe=",df.describe())
# Out:
# 0    10
# 1     3
# 2     5
# 3     4
# 4     6
# 5    70
# 6    12
# 7    45
# dtype: int64
# describe= count     8.000000
# mean     19.375000
# std      24.645704
# min       3.000000
# 25%       4.750000
# 50%       8.000000
# 75%      20.250000
# max      70.000000
# dtype: float64

# %% [raw]
# A = [90,3,1,2,None,6]
# df=pd.Series(A)
# df

# %%
# There are 3 function in pandas sloving a null value 
# 1. hasnans
#     hasans writen a single value True and False,hasans is a attributes
# 2. isnull
#     multiple boolen value writen 
# 3. notnull
#       isnull oppsite

# %% [markdown]
# ### HASNANS

# %%
A = [90,3,1,2,None,6]
df=pd.Series(A)
df.hasnans
# Out:
# True

# %% [markdown]
# ### ISNULL

# %%
A = [90,None,1,2,None,6]
df=pd.Series(A)
print(A)
df.isnull()
# Out:
# [90, None, 1, 2, None, 6]
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# dtype: bool

# %% [markdown]
# ### NOTNULL

# %%
A = [90,None,1,2,None,6]
df=pd.Series(A)
print(A)
df.notnull()
# Out:
# [90, None, 1, 2, None, 6]
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
import pandas as pd

# %%
W=[9,20,34,12,55,47]
W[3]=120
df=pd.Series(W)
df
# print(W)
# Out:
# 0      9
# 1     20
# 2     34
# 3    120
# 4     55
# 5     47
# dtype: int64

# %%
W=[9,20,34,12,55,47]
W[0:3]=[100,100,100]
df=pd.Series(W)
df
# print(W)
# Out:
# 0    100
# 1    100
# 2    100
# 3     12
# 4     55
# 5     47
# dtype: int64

# %%
# W=[9,20,34,12,55,47]
# W[0:3]=100
# print(W)
# df=pd.Series(W)
# print(df)

# %%
W=[100,2001,900,400,300,500]
S=pd.Series(W)
S[[0,2,5]]=1000
print(S)
# Out:
# 0    1000
# 1    2001
# 2    1000
# 3     400
# 4     300
# 5    1000
# dtype: int64

# %%
A=[12,3,45,68,12,9,68,10]
S=pd.Series(A)
print(S)
print(S.unique())
# Out:
# 0    12
# 1     3
# 2    45
# 3    68
# 4    12
# 5     9
# 6    68
# 7    10
# dtype: int64
# [12  3 45 68  9 10]

# %%
A=[12,3,45,68,12,9,68,10]
S=pd.Series(A)
print(S)
print(S.nunique())
# Out:
# 0    12
# 1     3
# 2    45
# 3    68
# 4    12
# 5     9
# 6    68
# 7    10
# dtype: int64
# 6

# %%
A=[12,3,45,68,12,9,68,10]
S=pd.Series(A)
print(len(S))
# Out:
# 8

# %%
A=[12,3,45,68,12,9,68,10]
S=pd.Series(A)
print(type(S))
# Out:
# <class 'pandas.core.series.Series'>

# %%
A=[12,3,45,68,12,9,68,10]
S=pd.Series(A)
print(sorted(S))
# Out:
# [3, 9, 10, 12, 12, 45, 68, 68]

# %%
A=[12,3,45,68,12,9,68,10]
S=pd.Series(A)
print(min(S))
# Out:
# 3

# %%
A=[12,3,45,68,12,9,68,10]
S=pd.Series(A)
print(max(S))
# Out:
# 68

# %%
A=[12,3,45,68,12,9,68,10]
S=pd.Series(A)
print(dir(S))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__bool__', '__class__', '__column_consortium_standard__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__firstlineno__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__
# ...

# %%
A=[10,34,89,12,45,6,56]
t=tuple(A)
print(t)
# Out:
# (10, 34, 89, 12, 45, 6, 56)

# %%
A=[1,2,3,4,5,6,7,8,9]
t=tuple(A)
print(t)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9)

# %%
A=[10,34,89,12,45,6,56]
t=pd.Series(A)
t=dict(t)
print(t)
# Out:
# {0: np.int64(10), 1: np.int64(34), 2: np.int64(89), 3: np.int64(12), 4: np.int64(45), 5: np.int64(6), 6: np.int64(56)}

# %%
B=["Amit","sumit","Ravindra","Amit"]
S=pd.Series(B)
print(S)
S=[89,60,70,70]
Score=pd.Series(S)
print(Score)
# Out:
# 0        Amit
# 1       sumit
# 2    Ravindra
# 3        Amit
# dtype: object
# 0    89
# 1    60
# 2    70
# 3    70
# dtype: int64

# %%
B=["Amit","sumit","Ravindra","Amit"]
S=pd.Series(B)
print(S)
S=[89,60,70,70]
Score=pd.Series(S)
print(Score)
city =["Bhopal","Indore","REWA","SATNA"]
city=pd.Series(S)
print(city)
# Out:
# 0        Amit
# 1       sumit
# 2    Ravindra
# 3        Amit
# dtype: object
# 0    89
# 1    60
# 2    70
# 3    70
# dtype: int64
# 0    89
# 1    60
# 2    70
# 3    70
# dtype: int64

# %%
A=[29,3,14,56,23,7,8]
df=pd.Series(A)
df
# Out:
# 0    29
# 1     3
# 2    14
# 3    56
# 4    23
# 5     7
# 6     8
# dtype: int64

# %%
#Membership operators in and not in (in operater index dekta hai)
print(3 in A)
# Out:
# True

# %%
print(8 in df) # cheack in index
# Out:
# False

# %%
print(8 in df.values) # cheack in value
# Out:
# True

# %%
print(9 not in df)
# Out:
# True

# %%
print(9 not in df.values)
# Out:
# True

# %%
# print(9 not in df.values)
for i in df:
    print(i)
print(df)
print(df+10) #broadcasting operator(Arithmetic operation)
# Out:
# 29
# 3
# 14
# 56
# 23
# 7
# 8
# 0    29
# 1     3
# 2    14
# 3    56
# 4    23
# 5     7
# 6     8
# dtype: int64
# 0    39
# 1    13
# 2    24
# 3    66
# 4    33
# 5    17
# 6    18
# dtype: int64

# %%
B=[100,20,3,45,60,8,90,56]
df=pd.Series(B)
print(df)
print(df[2])
print(df[2]>2)
# Out:
# 0    100
# 1     20
# 2      3
# 3     45
# 4     60
# 5      8
# 6     90
# 7     56
# dtype: int64
# 3
# True

# %% [markdown]
# ### value campare

# %%
B=[100,20,3,45,60,8,90,56] # es method ko intput mass bolte hai 
df=pd.Series(B)
print(df)
print(df[df>45])
# Out:
# 0    100
# 1     20
# 2      3
# 3     45
# 4     60
# 5      8
# 6     90
# 7     56
# dtype: int64
# 0    100
# 4     60
# 6     90
# 7     56
# dtype: int64

# %%
B=[100,20,3,45,60,8,90,56] # es method ko intput mass bolte hai 
df=pd.Series(B)
print(df)
print(df[df>45].values)
# Out:
# 0    100
# 1     20
# 2      3
# 3     45
# 4     60
# 5      8
# 6     90
# 7     56
# dtype: int64
# [100  60  90  56]

# %%
B=[100,20,3,45,60,8,90,3,100,20,56] # es method ko intput mass bolte hai 
df=pd.Series(B)
print(df)
print(df[df>45].values)
# Out:
# 0     100
# 1      20
# 2       3
# 3      45
# 4      60
# 5       8
# 6      90
# 7       3
# 8     100
# 9      20
# 10     56
# dtype: int64
# [100  60  90 100  56]

# %%
B=[100,20,3,45,60,8,90,56] # es method ko intput mass bolte hai 
df=pd.Series(B)
print(df)
print(df.values[df>45])
# Out:
# 0    100
# 1     20
# 2      3
# 3     45
# 4     60
# 5      8
# 6     90
# 7     56
# dtype: int64
# [100  60  90  56]

# %%
B=[100,20,3,45,60,8,90,3,100,20,56] # es method ko intput mass bolte hai 
df=pd.Series(B)
print(df)
print(df.values[df>45])
# Out:
# 0     100
# 1      20
# 2       3
# 3      45
# 4      60
# 5       8
# 6      90
# 7       3
# 8     100
# 9      20
# 10     56
# dtype: int64
# [100  60  90 100  56]

# %% [markdown]
# ### index

# %%
B=[100,20,3,45,60,8,90,56] # es method ko intput mass bolte hai 
df=pd.Series(B)
print(df)
print(df[df>45].index)
# Out:
# 0    100
# 1     20
# 2      3
# 3     45
# 4     60
# 5      8
# 6     90
# 7     56
# dtype: int64
# Index([0, 4, 6, 7], dtype='int64')

# %%
B=[100,20,3,45,60,8,90,56]
df=pd.Series(B)
print(df)
print(df[df>45].index)
# Out:
# 0    100
# 1     20
# 2      3
# 3     45
# 4     60
# 5      8
# 6     90
# 7     56
# dtype: int64
# Index([0, 4, 6, 7], dtype='int64')

# %%
B=[100,20,3,45,60,8,90,56,100,23,3]
df=pd.Series(B)
print(df)
print(df[df>45].value_counts())
# Out:
# 0     100
# 1      20
# 2       3
# 3      45
# 4      60
# 5       8
# 6      90
# 7      56
# 8     100
# 9      23
# 10      3
# dtype: int64
# 100    2
# 60     1
# 90     1
# 56     1
# Name: count, dtype: int64

# %%
B=[100,20,3,45,60,8,90,56,100,23,3]
df=pd.Series(B)
print(df)
print(df[df>45].count())
# Out:
# 0     100
# 1      20
# 2       3
# 3      45
# 4      60
# 5       8
# 6      90
# 7      56
# 8     100
# 9      23
# 10      3
# dtype: int64
# 5

# %%
B=[100,20,100,45,100,8,90,45]
df=pd.Series(B)
print(df)
print(df[df>45].count())
# Out:
# 0    100
# 1     20
# 2    100
# 3     45
# 4    100
# 5      8
# 6     90
# 7     45
# dtype: int64
# 4

# %%
B=[100,20,100,45,100,8,90,45]
df=pd.Series(B)
print(df)
print(df[df>45].min())
# Out:
# 0    100
# 1     20
# 2    100
# 3     45
# 4    100
# 5      8
# 6     90
# 7     45
# dtype: int64
# 90

# %%
B=[100,20,100,45,100,8,90,45]
df=pd.Series(B)
print(df)
print(df[df>45].max())
# Out:
# 0    100
# 1     20
# 2    100
# 3     45
# 4    100
# 5      8
# 6     90
# 7     45
# dtype: int64
# 100

# %%
# data fram is collation of series

# %%
df.head()
# Out:
# 0    100
# 1     20
# 2    100
# 3     45
# 4    100
# dtype: int64

# %%
df.tail()
# Out:
# 3     45
# 4    100
# 5      8
# 6     90
# 7     45
# dtype: int64

# %%
df.head().plot(kind='pie')
# Out:
# <Axes: >

# %%
df.head(3).plot(kind='pie')
# Out:
# <Axes: >

# %%
df.tail().plot(kind='pie')
# Out:
# <Axes: >
